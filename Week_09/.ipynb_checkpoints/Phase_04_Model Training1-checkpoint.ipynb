# %%
#Import Libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras.preprocessing.image import ImageDataGenerator



print("TensorFlow:", tf.__version__)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785136392.671234  208223 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1785136392.731914  208223 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785136394.349386  208223 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# TensorFlow: 2.21.0

# %%
#Load Dataset

train_df = pd.read_csv("Datasets/train.csv")
val_df = pd.read_csv("Datasets/val.csv")
test_df = pd.read_csv("Datasets/test.csv")

print(train_df.shape)
print(val_df.shape)
print(test_df.shape)
# Out:
# (7010, 9)
# (1502, 9)
# (1503, 9)

# %%
#Encode Labels
encoder = LabelEncoder()

train_df["label"] = encoder.fit_transform(train_df["dx"])
val_df["label"] = encoder.transform(val_df["dx"])
test_df["label"] = encoder.transform(test_df["dx"])

print(encoder.classes_)
# Out:
# ['akiec' 'bcc' 'bkl' 'df' 'mel' 'nv' 'vasc']

# %%
#Convert Labels to String

train_df["label"] = train_df["label"].astype(str)
val_df["label"] = val_df["label"].astype(str)
test_df["label"] = test_df["label"].astype(str)

# %%
#Compute Class Weights
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_df["label"]),
    y=train_df["label"]
)

class_weights = dict(enumerate(class_weights))

print(class_weights)
# Out:
# {0: np.float64(4.37305053025577), 1: np.float64(2.7817460317460316), 2: np.float64(1.3022478172023035), 3: np.float64(12.36331569664903), 4: np.float64(1.285530900421786), 5: np.float64(0.21338772031292808), 6: np.float64(10.115440115440116)}

# %%
#Constants
IMG_SIZE = 224
BATCH_SIZE = 32

# %%
#Data Augmentation
train_datagen = ImageDataGenerator(

    rescale=1./255,

    rotation_range=15,

    zoom_range=0.10,

    horizontal_flip=True,

    fill_mode="nearest"

)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
#Create Generators
train_generator = train_datagen.flow_from_dataframe(

    dataframe=train_df,

    x_col="path",

    y_col="label",

    target_size=(IMG_SIZE, IMG_SIZE),

    batch_size=BATCH_SIZE,

    class_mode="categorical",

    shuffle=True
)
# Out:
# Found 7010 validated image filenames belonging to 7 classes.

# %%
#Validation
val_generator = test_datagen.flow_from_dataframe(

    dataframe=val_df,

    x_col="path",

    y_col="label",

    target_size=(IMG_SIZE, IMG_SIZE),

    batch_size=BATCH_SIZE,
#RGB Channel Distribution
r = []
g = []
b = []

for path in metadata.sample(100)["path"]:

    image = cv2.imread(path)

    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

    r.extend(image[:,:,0].flatten())
    g.extend(image[:,:,1].flatten())
    b.extend(image[:,:,2].flatten())
    class_mode="categorical",

    shuffle=False
)
#Test
test_generator = test_datagen.flow_from_dataframe(

    dataframe=test_df,

    x_col="path",

    y_col="label",

    target_size=(IMG_SIZE, IMG_SIZE),

    batch_size=BATCH_SIZE,

    class_mode="categorical",

    shuffle=False
)
#Check Images
images, labels = next(train_generator)

plt.figure(figsize=(12,6))

for i in range(6):

    plt.subplot(2,3,i+1)

    plt.imshow(images[i])

    plt.title(np.argmax(labels[i]))

    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Found 1502 validated image filenames belonging to 7 classes.
# Found 1503 validated image filenames belonging to 7 classes.

# %%
#Build Basic CNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    GlobalAveragePooling2D,
    Dense,
    Dropout
)
from tensorflow.keras.optimizers import Adam

basic_cnn = Sequential([

    Conv2D(32, (3,3), activation="relu", input_shape=(128,128,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D(2,2),

    GlobalAveragePooling2D(),

    Dense(128, activation="relu"),

    Dense(7, activation="softmax")

])

basic_cnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,615 (111.78 KB)
#  Trainable params: 28,615 (111.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compile Model
basic_cnn.compile(

    optimizer=Adam(learning_rate=0.0001),

    loss="categorical_crossentropy",

    metrics=["accuracy"]

)

# %%
#Train model
history_basic = basic_cnn.fit(

    train_generator,

    validation_data=val_generator,

    epochs=10,

    class_weight=class_weights

)
# Out:
# Epoch 1/10
# W0000 00:00:1785136657.596820  208271 cpu_allocator_impl.cc:82] Allocation of 201867264 exceeds 10% of free system memory.
# W0000 00:00:1785136658.492026  208272 cpu_allocator_impl.cc:82] Allocation of 201867264 exceeds 10% of free system memory.
#   1/220 ━━━━━━━━━━━━━━━━━━━━ 12:01 3s/step - accuracy: 0.6250 - loss: 4.0114
# W0000 00:00:1785136658.967615  208271 cpu_allocator_impl.cc:82] Allocation of 201867264 exceeds 10% of free system memory.
# W0000 00:00:1785136659.941783  208273 cpu_allocator_impl.cc:82] Allocation of 201867264 exceeds 10% of free system memory.
#   2/220 ━━━━━━━━━━━━━━━━━━━━ 5:22 1s/step - accuracy: 0.6562 - loss: 2.8604
# W0000 00:00:1785136660.447082  208270 cpu_allocator_impl.cc:82] Allocation of 201867264 exceeds 10% of free system memory.
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 339s 2s/step - accuracy: 0.4472 - loss: 1.9435 - val_accuracy: 0.4607 - val_loss: 1.9048
# Epoch 2/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 339s 2s/step - accuracy: 0.4351 - loss: 1.9321 - val_accuracy: 0.4268 - val_loss: 1.8965
# Epoch 3/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - accuracy: 0.4047 - loss: 1.9144 - val_accuracy: 0.3895 - val_loss: 1.8113
# Epoch 4/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 396s 2s/step - accuracy: 0.3892 - loss: 1.8929 - val_accuracy: 0.4441 - val_loss: 1.7001
# Epoch 5/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.4251 - loss: 1.8729 - val_accuracy: 0.4387 - val_loss: 1.7081
# Epoch 6/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 320s 1s/step - accuracy: 0.4258 - loss: 1.8624 - val_accuracy: 0.4554 - val_loss: 1.6636
# Epoch 7/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 314s 1s/step - accuracy: 0.4201 - loss: 1.8548 - val_accuracy: 0.4541 - val_loss: 1.5973
# Epoch 8/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.4300 - loss: 1.8514 - val_accuracy: 0.4354 - val_loss: 1.6993
# Epoch 9/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.4404 - loss: 1.8405 - val_accuracy: 0.4374 - val_loss: 1.6680
# Epoch 10/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.4435 - loss: 1.8264 - val_accuracy: 0.4940 - val_loss: 1.6809

# %%
#Evaluate Model
test_loss, test_acc = basic_cnn.evaluate(test_generator)

print(test_acc)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 494ms/step - accuracy: 0.4544 - loss: 1.7220
# 0.4544244706630707

# %%
Flatten()

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

pred = basic_cnn.predict(test_generator)

pred_labels = np.argmax(pred, axis=1)

true_labels = test_generator.classes

accuracy_1 = accuracy_score(true_labels, pred_labels)

precision_1 = precision_score(
    true_labels,
    pred_labels,
    average="weighted"
)

recall_1 = recall_score(
    true_labels,
    pred_labels,
    average="weighted"
)

f1_1 = f1_score(
    true_labels,
    pred_labels,
    average="weighted"
)

print("Accuracy :", accuracy_1)
print("Precision:", precision_1)
print("Recall :", recall_1)
print("F1 :", f1_1)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 419ms/step
# Accuracy : 0.45442448436460414
# Precision: 0.6854924175009779
# Recall : 0.45442448436460414
# F1 : 0.5107562624277135
# /home/aximsoft/jupyter-env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
train_acc =history_basic.history["accuracy"][-1]

val_acc = history_basic.history["val_accuracy"][-1]

train_loss = history_basic.history["loss"][-1]

val_loss = history_basic.history["val_loss"][-1]
print(val_acc)
# Out:
# 0.49400797486305237

# %%
#Save Model
basic_cnn.save("models/basic_cnn1.keras")

# %%
#Predictions
predictions = basic_cnn.predict(test_generator)

predicted_labels = np.argmax(predictions, axis=1)

true_labels = test_generator.classes
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 475ms/step

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=encoder.classes_,
    yticklabels=encoder.classes_
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# %%
#Build Deep CNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    GlobalAveragePooling2D,
    Dense,
    Dropout
)
from tensorflow.keras.optimizers import Adam

deep_cnn = Sequential([

    Conv2D(32,(3,3),activation="relu",padding="same",input_shape=(128,128,3)),
    MaxPooling2D(),

    Conv2D(64,(3,3),activation="relu",padding="same"),
    MaxPooling2D(),

    Conv2D(128,(3,3),activation="relu",padding="same"),
    MaxPooling2D(),

    Conv2D(256,(3,3),activation="relu",padding="same"),
    MaxPooling2D(),

    GlobalAveragePooling2D(),

    Dense(256,activation="relu"),

    Dense(128,activation="relu"),

    Dense(7,activation="softmax")

])

deep_cnn.summary()
# Out:
# /home/aximsoft/jupyter-env/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 488,007 (1.86 MB)
#  Trainable params: 488,007 (1.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compile Model
deep_cnn.compile(

    optimizer=Adam(learning_rate=0.0001),

    loss="categorical_crossentropy",

    metrics=["accuracy"]

)

# %%
#Train Model
history_deep = deep_cnn.fit(

    train_generator,

    validation_data=val_generator,

    epochs=10,

    class_weight=class_weights

)
# Evaluate
test_loss, test_acc = deep_cnn.evaluate(test_generator)

print(f"Test Accuracy : {test_acc:.4f}")
print(f"Test Loss : {test_loss:.4f}")
# Out:
# Epoch 1/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 555s 3s/step - accuracy: 0.0723 - loss: 1.9463 - val_accuracy: 0.2716 - val_loss: 1.9479
# Epoch 2/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 540s 2s/step - accuracy: 0.4050 - loss: 1.9014 - val_accuracy: 0.4807 - val_loss: 1.5625
# Epoch 3/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 535s 2s/step - accuracy: 0.4077 - loss: 1.8580 - val_accuracy: 0.3356 - val_loss: 1.8918
# Epoch 4/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 548s 2s/step - accuracy: 0.4254 - loss: 1.7767 - val_accuracy: 0.4947 - val_loss: 1.3466
# Epoch 5/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1047s 5s/step - accuracy: 0.4384 - loss: 1.6913 - val_accuracy: 0.4334 - val_loss: 1.5807
# Epoch 6/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 641s 3s/step - accuracy: 0.4472 - loss: 1.6376 - val_accuracy: 0.4754 - val_loss: 1.3495
# Epoch 7/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 725s 3s/step - accuracy: 0.4576 - loss: 1.5838 - val_accuracy: 0.4154 - val_loss: 1.6088
# Epoch 8/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 789s 4s/step - accuracy: 0.4655 - loss: 1.5255 - val_accuracy: 0.5206 - val_loss: 1.2048
# Epoch 9/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 677s 3s/step - accuracy: 0.4678 - loss: 1.4586 - val_accuracy: 0.4874 - val_loss: 1.3140
# Epoch 10/10
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 756s 3s/step - accuracy: 0.4752 - loss: 1.4083 - val_accuracy: 0.4887 - val_loss: 1.2679
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 33s 697ms/step - accuracy: 0.4910 - loss: 1.3057
# Test Accuracy : 0.4910
# Test Loss : 1.3057

# %%
#Evaluate
test_loss, test_acc = deep_cnn.evaluate(test_generator)

print(test_acc)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 42s 888ms/step - accuracy: 0.4910 - loss: 1.3057
# 0.4910179674625397

# %%
#Save Model
deep_cnn.save("models/deep_cnn1.keras")
