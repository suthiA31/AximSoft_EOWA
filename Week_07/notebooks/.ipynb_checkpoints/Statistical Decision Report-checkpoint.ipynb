# %% [markdown]
# # Phase 7 - Statistical Decision Report
#
# ## Objectives
#
# This report summarizes the statistical analysis performed on the Hotel Booking Demand dataset.
#
# ### Report Includes
#
# - Assumption Testing Results
# - Selected Statistical Tests
# - Hypothesis Testing Outcomes
# - Statistical Significance
# - Business Conclusions
# - Key Recommendations
#
# The report provides a concise summary of the statistical findings and their business implications.

# %%
import pandas as pd
assumption_summary = pd.DataFrame({

"Assumption":[
"Normality",
"Homogeneity of Variance",
"Independence",
"Correlation",
"Multicollinearity"
],

"Method":[
"Shapiro-Wilk",
"Levene Test",
"Duplicate Check",
"Pearson Correlation",
"VIF"
],

"Result":[
"Validated",
"Validated",
"Validated",
"Validated",
"Validated"
]

})

assumption_summary
# Out:
#                 Assumption               Method     Result
# 0                Normality         Shapiro-Wilk  Validated
# 1  Homogeneity of Variance          Levene Test  Validated
# 2             Independence      Duplicate Check  Validated
# 3              Correlation  Pearson Correlation  Validated
# 4        Multicollinearity                  VIF  Validated

# %%
#Statistical Tests Summary
test_summary = pd.DataFrame({

"Statistical Test":[
"Independent t-Test",
"Paired t-Test",
"One-Way ANOVA",
"Pearson Correlation",
"Chi-Square Test",
"Mann-Whitney U Test",
"Kruskal-Wallis Test",
"Spearman Correlation"
],

"Purpose":[
"Compare ADR between hotel types",
"Compare weekday and weekend stays",
"Compare ADR among customer types",
"Relationship between Lead Time and ADR",
"Association between Hotel Type and Cancellation",
"Compare ADR distributions",
"Compare customer groups",
"Monotonic relationship"
]

})

test_summary
# Out:
#        Statistical Test                                          Purpose
# 0    Independent t-Test                  Compare ADR between hotel types
# 1         Paired t-Test                Compare weekday and weekend stays
# 2         One-Way ANOVA                 Compare ADR among customer types
# 3   Pearson Correlation           Relationship between Lead Time and ADR
# 4       Chi-Square Test  Association between Hotel Type and Cancellation
# 5   Mann-Whitney U Test                        Compare ADR distributions
# 6   Kruskal-Wallis Test                          Compare customer groups
# 7  Spearman Correlation                           Monotonic relationship

# %%
#Hypothesis Testing Outcome
hypothesis = pd.DataFrame({

"Test":[
"Independent t-Test",
"Paired t-Test",
"One-Way ANOVA",
"Pearson",
"Chi-Square",
"Mann-Whitney",
"Kruskal-Wallis",
"Spearman"
],

"Decision":[
"Reject H₀",
"Reject H₀",
"Reject H₀",
"Reject H₀",
"Reject H₀",
"Reject H₀",
"Reject H₀",
"Reject H₀"
]

})

hypothesis
# Out:
#                  Test   Decision
# 0  Independent t-Test  Reject H₀
# 1       Paired t-Test  Reject H₀
# 2       One-Way ANOVA  Reject H₀
# 3             Pearson  Reject H₀
# 4          Chi-Square  Reject H₀
# 5        Mann-Whitney  Reject H₀
# 6      Kruskal-Wallis  Reject H₀
# 7            Spearman  Reject H₀

# %%
#Statistical Significance
significance = pd.DataFrame({

"Significance Level":[0.05],

"Confidence Level":["95%"],

"Decision Rule":[
"Reject H₀ if p-value < 0.05"
]

})

significance
# Out:
#    Significance Level Confidence Level                Decision Rule
# 0                0.05              95%  Reject H₀ if p-value < 0.05

# %%
#Business Conclusions
business = pd.DataFrame({

"Business Findings":[

"Booking demand varies across seasons.",

"Hotel type significantly influences Average Daily Rate (ADR).",

"Customer type affects hotel revenue.",

"Lead time is associated with booking cancellation.",

"Market segment impacts booking behavior.",

"Repeat guests contribute to stable booking patterns.",

"Long lead-time bookings show higher cancellation tendencies."

]

})

business
# Out:
#                                    Business Findings
# 0              Booking demand varies across seasons.
# 1  Hotel type significantly influences Average Da...
# 2               Customer type affects hotel revenue.
# 3  Lead time is associated with booking cancellat...
# 4           Market segment impacts booking behavior.
# 5  Repeat guests contribute to stable booking pat...
# 6  Long lead-time bookings show higher cancellati...
